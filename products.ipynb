# %%
import pandas as pd

# %%
 chemin = 'C:\\Users\\corvi\\Data\\LOREAL_B2B_products.csv'
df_4 = pd.read_csv(chemin)

# %%
df_4
# Out:
#                                    productId       brand      productName  \
# 0       p3300627-302c-4d96-9297-a46202982f6f  Shu Uemura     Heavy Indeed
# 1       pe16711e-1a06-4304-9fb7-c1f6f3a50711  Loreal Pro   Nothing Method
# 2       pd83555d-9475-469d-926f-5ca33576d3f0  Shu Uemura       Your Focus
# 3       p6154a42-6470-41f3-bfbc-f1c7d37407b7   Kerastase      Source Born
# 4       p2cb3fab-61fc-4c7a-ad8f-06140c952705  Loreal Pro  Central Defense
# ...                                      ...         ...              ...
# 112516  p209fc00-8c72-4d1c-aad0-dd35e33dcf94   Kerastase       Amount One
# 112517  p6bf8009-81f5-4f40-9865-23370e897ec5   Kerastase      Line Indeed
# 112518  p006ebad-70a0-45c7-88b0-d9cb8e6e5fbe  Shu Uemura         Girl Ten
# 112519  p2958b4c-5a55-4e9d-ad64-0149323e4792  Shu Uemura       Paper Onto
# 112520  pd3e6a87-10bc-4931-b040-f977c98fa65e   Kerastase      Show Beyond
#
#        productCategory
# 0            Hair Care
# 1                 Mask
# ...
