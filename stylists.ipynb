# %%
import pandas as pd

# %%
 chemin = 'C:\\Users\\corvi\\Data\\LOREAL_B2B_stylists.csv'
df_6 = pd.read_csv(chemin)

# %%
df_6
# Out:
#              country                             stylistId  \
# 0             Poland  h856c19a-d0eb-465d-8393-c03cfba899a9
# 1             Poland  h41dedac-e1d8-44d6-8393-fff104697ba8
# 2             Poland  h410b301-8959-45f0-8244-dc5fbcbd4ce4
# 3             Poland  he3567e5-fa68-4043-9c54-f7c1304e751e
# 4             Poland  h9574f20-744e-44da-be89-abd15f7e3fa7
# ...              ...                                   ...
# 1902  United Kingdom  h490f5cc-27ea-438b-a252-1b5c1f4e64d0
# 1903     Netherlands  haa8e620-0967-4092-925d-c55e0d7b9d77
# 1904     Netherlands  h4dfca57-c32b-4bd7-a0b0-bd836b71925e
# 1905         Germany  h45389b7-2623-4a6c-8b6e-1ffea2c66b61
# 1906         Germany  he16f679-fda7-45bd-a865-b66a540f17d9
#
#                                    salonId systemCreationDate  firstName  \
# 0     a2f9683b-53fa-417b-9ea9-4f98dae19e9b         2021-04-12        NaN
# 1     a2f9683b-53fa-417b-9ea9-4f98dae19e9b         2017-09-23        NaN
# ...
