# %%
import pandas as pd

# %%
 chemin = 'C:\\Users\\corvi\\Data\\LOREAL_B2B_order_lines.csv'
df_2 = pd.read_csv(chemin)

# %%
df_2
# Out:
#         country                               orderId  \
# 0        Poland  offe5ceb-3956-4ea2-87be-b53eabaecb01
# 1        Poland  offe5ceb-3956-4ea2-87be-b53eabaecb01
# 2        Poland  o6b8f4e9-f3a3-4132-9634-f175fedecaf7
# 3        Poland  o6b8f4e9-f3a3-4132-9634-f175fedecaf7
# 4        Poland  o6b8f4e9-f3a3-4132-9634-f175fedecaf7
# ...         ...                                   ...
# 112516  Germany  o714b08f-f802-4dc9-89ff-5199d17144e4
# 112517  Germany  o714b08f-f802-4dc9-89ff-5199d17144e4
# 112518  Germany  o714b08f-f802-4dc9-89ff-5199d17144e4
# 112519  Germany  o714b08f-f802-4dc9-89ff-5199d17144e4
# 112520  Germany  o714b08f-f802-4dc9-89ff-5199d17144e4
#
#                                      salonId        orderDateTime  \
# 0       a2f9683b-53fa-417b-9ea9-4f98dae19e9b  2019-04-18 05:20:16
# 1       a2f9683b-53fa-417b-9ea9-4f98dae19e9b  2019-04-18 05:20:16
# 2       a2f9683b-53fa-417b-9ea9-4f98dae19e9b  2023-04-13 20:59:56
# ...

# %%
df_2.to_csv('order_lines_2.csv', index=False)
